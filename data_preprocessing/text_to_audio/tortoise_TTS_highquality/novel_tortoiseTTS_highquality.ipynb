# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install tortoise-tts scipy
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: tortoise-tts in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (4.66.6)
# Requirement already satisfied: rotary-embedding-torch in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (0.8.5)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (7.4.0)
# Requirement already satisfied: progressbar in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (2.5)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (0.8.0)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (1.3.8)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (0.10.2.post1)
# Requirement already satisfied: transformers==4.31.0 in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (4.31.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from tortoise-tts) (0.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->tortoise-tts) (0.4.5)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect->tortoise-tts) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect->tortoise-tts) (4.4.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->tortoise-tts) (1.1.0)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.10/dist-packages (from rotary-embedding-torch->tortoise-tts) (2.5.1+cu121)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0->tortoise-tts) (2024.10.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->tortoise-tts) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa->tortoise-tts) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->tortoise-tts) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->tortoise-tts) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->tortoise-tts) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->tortoise-tts) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->tortoise-tts) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa->tortoise-tts) (1.17.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->rotary-embedding-torch->tortoise-tts) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->rotary-embedding-torch->tortoise-tts) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->rotary-embedding-torch->tortoise-tts) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0->rotary-embedding-torch->tortoise-tts) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->tortoise-tts) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0->rotary-embedding-torch->tortoise-tts) (3.0.2)

# %%
# !pip install deepspeed
# Out:
# Collecting deepspeed
#   Downloading deepspeed-0.15.4.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting hjson (from deepspeed)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from deepspeed) (1.1.0)
# Collecting ninja (from deepspeed)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deepspeed) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from deepspeed) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from deepspeed) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed) (9.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from deepspeed) (2.9.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from deepspeed) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deepspeed) (4.66.6)
# Collecting nvidia-ml-py (from deepspeed)
#   Downloading nvidia_ml_py-12.560.30-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0.0->deepspeed) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0.0->deepspeed) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0.0->deepspeed) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->deepspeed) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->deepspeed) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->deepspeed) (3.0.2)
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.2 MB/s eta 0:00:00
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 28.1 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.560.30-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.9 MB/s eta 0:00:00
# Building wheels for collected packages: deepspeed
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.15.4-py3-none-any.whl size=1527834 sha256=f839be2a146a608f12e14d784fc23bf760c1f2719aeadd0f88eeb661d2ab1da6
#   Stored in directory: /root/.cache/pip/wheels/74/bc/b6/836d7c3e3093e25502fa9248e0be9e943db245f2806ba1cd19
# Successfully built deepspeed
# Installing collected packages: nvidia-ml-py, ninja, hjson, deepspeed
# Successfully installed deepspeed-0.15.4 hjson-3.1.0 ninja-1.11.1.1 nvidia-ml-py-12.560.30

# %%
import os
import numpy as np
import torch
from tortoise.api import TextToSpeech
from scipy.io.wavfile import write
import json
from google.colab import drive  # Google 드라이브 마운트

# Google 드라이브 마운트
drive.mount('/content/drive')

# Google 드라이브에 저장할 루트 폴더 설정
output_root_folder = '/content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel'
os.makedirs(output_root_folder, exist_ok=True)

# A100 GPU 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    print(f"GPU 활성화: {gpu_name}")
    if "A100" not in gpu_name:
        print("⚠️ GPU가 A100이 아닙니다. 런타임 유형 설정에서 'A100 GPU'로 변경하세요.")
else:
    print("GPU를 사용할 수 없습니다. CPU로 실행됩니다.")

# 저장된 임베딩 로드 및 Tensor로 변환
embedding_path = "conditioning_latents_Mark.npz"  # 본인 경로에 맞게 설정
loaded_latents = np.load(embedding_path)
conditioning_latents = [torch.tensor(loaded_latents[key]).to(device) for key in loaded_latents]

# Tortoise TTS 모델 초기화 (A100 GPU 최적화 설정)
tts = TextToSpeech(use_deepspeed=True, kv_cache=True, half=True, device=device)

# JSON 파일 경로 설정
json_path = "novel.json"  # 본인 경로에 맞게 설정

# JSON 파일 읽기
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# JSON 데이터를 바탕으로 음성 파일 생성 및 저장
for category in data["categories"]:
    category_name = category["category_name"]
    for level in category["levels"]:
        level_number = level["level"]

        # level이 6에서 10 사이인 경우에만 음성 변환 수행
        if level_number < 6 or level_number > 10:
            continue

        for script in level["scripts"]:
            title = script["title"]
            contents = script["contents"]

            # Google 드라이브에 카테고리/레벨/타이틀 경로 생성
            output_folder = os.path.join(output_root_folder, category_name, f"level_{level_number}", title)
            os.makedirs(output_folder, exist_ok=True)

            # 각 문장을 한 줄씩 읽어 음성 변환 및 저장
            for i, text in enumerate(contents, 1):
                if not text.strip():
                    continue

                # 출력 파일 경로
                output_path = os.path.join(output_folder, f"{title}_line_{i}.wav")

                # 파일이 이미 존재하면 건너뛰기
                if os.path.exists(output_path):
                    print(f"이미 생성된 파일: {output_path}. 건너뜁니다.")
                    continue

                # 텍스트를 화자 샘플의 스타일로 음성 변환 (High Quality 설정)
                pcm_audio = tts.tts_with_preset(
                    text, conditioning_latents=conditioning_latents, preset="high_quality"
                )

                # PCM 데이터를 numpy 배열로 변환 후 최종 WAV 파일로 저장
                write(output_path, 22050, np.array(pcm_audio, dtype=np.float32))
                print(f"'{text}' 문장이 '{output_path}'로 저장되었습니다.")

print("레벨 6~10에 대한 텍스트 파일의 음성 변환이 완료되었습니다.")
# Out:
# Mounted at /content/drive
# GPU 활성화: NVIDIA A100-SXM4-40GB
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:460: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# Some weights of the model checkpoint at jbetker/wav2vec2-large-robust-ft-libritts-voxpopuli were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at jbetker/wav2vec2-large-robust-ft-libritts-voxpopuli and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# autoregressive.pth:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/tortoise/api.py:217: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.autoregressive.load_state_dict(torch.load(get_model_path('autoregressive.pth', models_dir)), strict=False)
# [2024-11-17 23:15:29,665] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-11-17 23:15:32,606] [INFO] [logging.py:128:log_dist] [Rank -1] DeepSpeed info: version=0.15.4, git-hash=unknown, git-branch=unknown
# [2024-11-17 23:15:32,608] [WARNING] [config_utils.py:70:_process_deprecated_field] Config parameter mp_size is deprecated use tensor_parallel.tp_size instead
# [2024-11-17 23:15:32,609] [INFO] [logging.py:128:log_dist] [Rank -1] quantize_bits = 8 mlp_extra_grouping = False, quantize_groups = 1
# [2024-11-17 23:15:32,706] [INFO] [logging.py:128:log_dist] [Rank -1] DeepSpeed-Inference config: {'layer_id': 0, 'hidden_size': 1024, 'intermediate_size': 4096, 'heads': 16, 'num_hidden_layers': -1, 'dtype': torch.float16, 'pre_layer_norm': True, 'norm_type': <NormType.LayerNorm: 1>, 'local_rank': -1, 'stochastic_mode': False, 'epsilon': 1e-05, 'mp_size': 1, 'scale_attention': True, 'triangular_masking': True, 'local_attention': False, 'window_size': 1, 'rotary_dim': -1, 'rotate_half': False, 'rotate_every_two': True, 'return_tuple': True, 'mlp_after_attn': True, 'mlp_act_func_type': <ActivationFuncType.GELU: 1>, 'training_mp_size': 1, 'bigscience_bloom': False, 'max_out_tokens': 1024, 'min_out_tokens': 1, 'scale_attn_by_inverse_layer_idx': False, 'enable_qkv_quantization': False, 'use_mup': False, 'return_single_tuple': False, 'set_empty_params': False, 'transposed_mode': False, 'use_triton': False, 'triton_autotune': False, 'num_kv': -1, 'rope_theta': 10000, 'invert_mask': True}
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py310_cu121/transformer_inference...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/transformer_inference/build.ninja...
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module transformer_inference...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module transformer_inference...
# Time to load transformer_inference op: 45.76247024536133 seconds
# diffusion_decoder.pth:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/tortoise/api.py:223: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.diffusion.load_state_dict(torch.load(get_model_path('diffusion_decoder.pth', models_dir)))
# clvp2.pth:   0%|          | 0.00/976M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/tortoise/api.py:229: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.clvp.load_state_dict(torch.load(get_model_path('clvp2.pth', models_dir)))
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# vocoder.pth:   0%|          | 0.00/391M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/tortoise/api.py:233: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.vocoder.load_state_dict(torch.load(get_model_path('vocoder.pth', models_dir), map_location=torch.device('cpu'))['model_g'])
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Firekeeper’s Quest/The Firekeeper’s Quest_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Bamboo Prince and the Sorcerer’s Challenge/The Bamboo Prince and the Sorcerer’s Challenge_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Weaver’s Journey Across the Stars/The Weaver’s Journey Across the Stars_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Weaver’s Journey Across the Stars/The Weaver’s Journey Across the Stars_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Weaver’s Journey Across the Stars/The Weaver’s Journey Across the Stars_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Weaver’s Journey Across the Stars/The Weaver’s Journey Across the Stars_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Weaver’s Journey Across the Stars/The Weaver’s Journey Across the Stars_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Weaver’s Journey Across the Stars/The Weaver’s Journey Across the Stars_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Weaver’s Journey Across the Stars/The Weaver’s Journey Across the Stars_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Scholar and the Spirit of Knowledge/The Scholar and the Spirit of Knowledge_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Scholar and the Spirit of Knowledge/The Scholar and the Spirit of Knowledge_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Scholar and the Spirit of Knowledge/The Scholar and the Spirit of Knowledge_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Scholar and the Spirit of Knowledge/The Scholar and the Spirit of Knowledge_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Scholar and the Spirit of Knowledge/The Scholar and the Spirit of Knowledge_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Scholar and the Spirit of Knowledge/The Scholar and the Spirit of Knowledge_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Scholar and the Spirit of Knowledge/The Scholar and the Spirit of Knowledge_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Celestial Archer/The Celestial Archer_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Celestial Archer/The Celestial Archer_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Celestial Archer/The Celestial Archer_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Celestial Archer/The Celestial Archer_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Celestial Archer/The Celestial Archer_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Celestial Archer/The Celestial Archer_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Celestial Archer/The Celestial Archer_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The River Spirit’s Gift/The River Spirit’s Gift_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Guardian of the Forest/The Guardian of the Forest_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Phoenix’s Feather/The Phoenix’s Feather_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Fisherman’s Promise/The Fisherman’s Promise_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_6/The Enchanted Garden/The Enchanted Garden_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Sorceress of the Hidden Falls/The Sorceress of the Hidden Falls_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Enchanted Sage of the Ironwood Forest/The Enchanted Sage of the Ironwood Forest_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Stone Cutter’s Redemption/The Stone Cutter’s Redemption_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Daughters of the Moonlit Sea/The Daughters of the Moonlit Sea_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Silent Flute of the Forgotten Valley/The Silent Flute of the Forgotten Valley_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Willow of Eternal Sorrow/The Willow of Eternal Sorrow_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Star Weaver’s Bargain/The Star Weaver’s Bargain_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Immortal Phoenix’s Ashes/The Immortal Phoenix’s Ashes_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Wanderer’s Song/The Wanderer’s Song_line_10.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_1.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_2.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_3.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_4.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_5.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_6.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_7.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_8.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_9.wav. 건너뜁니다.
# 이미 생성된 파일: /content/drive/MyDrive/Colab_Notebooks/tortoise_tts_high_quality_novel/novel/level_7/The Dragon and the Scholar’s Dilemma/The Dragon and the Scholar’s Dilemma_line_10.wav. 건너뜁니다.
# 레벨 6~10에 대한 텍스트 파일의 음성 변환이 완료되었습니다.
